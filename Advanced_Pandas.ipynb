# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([1,5,8, np.nan, 10, 12, 16, np.nan])

# %%
dates = pd.date_range("20130112","20240111",periods=12)

# %%
dates
# Out:
# DatetimeIndex([          '2013-01-12 00:00:00',
#                '2014-01-12 02:10:54.545454544',
#                '2015-01-12 04:21:49.090909088',
#                '2016-01-12 06:32:43.636363632',
#                '2017-01-11 08:43:38.181818176',
#                '2018-01-11 10:54:32.727272704',
#                '2019-01-11 13:05:27.272727264',
#                '2020-01-11 15:16:21.818181824',
#                '2021-01-10 17:27:16.363636352',
#                '2022-01-10 19:38:10.909090880',
#                '2023-01-10 21:49:05.454545408',
#                          '2024-01-11 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates[0].day
# Out:
# 12

# %%
ids = list("BSJA")
df = pd.DataFrame(np.random.randn(12,4), index=dates, columns=ids)

# %%
df
# Out:
#                                       B         S         J         A
# 2013-01-12 00:00:00.000000000 -0.243044 -0.043847 -0.120174  0.362442
# 2014-01-12 02:10:54.545454544  0.255213 -0.751955  0.409546  0.193926
# 2015-01-12 04:21:49.090909088 -1.238056  1.288997  0.586629 -1.136225
# 2016-01-12 06:32:43.636363632  0.276234  0.357685 -0.903688 -0.307291
# 2017-01-11 08:43:38.181818176 -0.416452  0.091228  0.373709 -0.424968
# 2018-01-11 10:54:32.727272704 -0.203303  1.200429  0.100454 -0.803684
# 2019-01-11 13:05:27.272727264 -0.339523  0.044399 -0.033089  0.094956
# 2020-01-11 15:16:21.818181824 -0.340064  0.211631  1.127301 -0.254531
# 2021-01-10 17:27:16.363636352  1.628415  0.500079  0.625511  1.296714
# 2022-01-10 19:38:10.909090880  1.295284  0.358820 -0.444901  0.183427
# 2023-01-10 21:49:05.454545408  1.422142  0.359905  0.062133 -1.457370
# 2024-01-11 00:00:00.000000000  0.376687 -0.051869  0.117332 -0.458123

# %%
type(dates)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
names = ["Bob", "Sam", "Jim", "Amy"]
df_names = pd.DataFrame(np.random.randn(4,4),index=list(names))

# %%
df_names
# Out:
#             0         1         2         3
# Bob -0.025482 -0.313752  0.167683 -0.286661
# Sam -1.591310 -0.808135  0.514874  0.535991
# Jim -0.294750 -0.663629  0.821033  0.686453
# Amy  1.479708  0.452908 -1.155061 -0.857444

# %%
new_df = pd.DataFrame(
    {
        "Values":12.2,
        "Dates": pd.Timestamp("20230122"),
        "Test": pd.Series(1, index=list(range(4)), dtype="float16"),
        "Numpy": np.array([3] * 4, dtype="int8"),
        "Categories": pd.Categorical(["Happy","Sad","Happy","Sad"])
    }
)

# %%
new_df
# Out:
#    Values      Dates  Test  Numpy Categories
# 0    12.2 2023-01-22   1.0      3      Happy
# 1    12.2 2023-01-22   1.0      3        Sad
# 2    12.2 2023-01-22   1.0      3      Happy
# 3    12.2 2023-01-22   1.0      3        Sad

# %%
new_df.dtypes
# Out:
# Values               float64
# Dates         datetime64[ns]
# Test                 float16
# Numpy                   int8
# Categories          category
# dtype: object

# %%
df.head()
# Out:
#                                       B         S         J         A
# 2013-01-12 00:00:00.000000000 -0.243044 -0.043847 -0.120174  0.362442
# 2014-01-12 02:10:54.545454544  0.255213 -0.751955  0.409546  0.193926
# 2015-01-12 04:21:49.090909088 -1.238056  1.288997  0.586629 -1.136225
# 2016-01-12 06:32:43.636363632  0.276234  0.357685 -0.903688 -0.307291
# 2017-01-11 08:43:38.181818176 -0.416452  0.091228  0.373709 -0.424968

# %%
df.to_numpy()
# Out:
# array([[-0.24304364, -0.04384707, -0.12017393,  0.36244185],
#        [ 0.2552132 , -0.7519552 ,  0.40954605,  0.19392643],
#        [-1.23805612,  1.28899654,  0.58662924, -1.13622492],
#        [ 0.27623435,  0.35768459, -0.90368761, -0.3072913 ],
#        [-0.41645179,  0.09122794,  0.37370902, -0.42496835],
#        [-0.20330315,  1.20042947,  0.10045433, -0.80368386],
#        [-0.33952272,  0.04439936, -0.03308874,  0.09495621],
#        [-0.34006397,  0.21163116,  1.12730051, -0.25453117],
#        [ 1.62841526,  0.50007934,  0.62551103,  1.29671396],
#        [ 1.29528444,  0.35882036, -0.44490091,  0.18342695],
#        [ 1.42214216,  0.35990532,  0.06213328, -1.45737003],
#        [ 0.37668702, -0.05186868,  0.11733227, -0.45812266]])

# %%
df.T
# Out:
#    2013-01-12 00:00:00.000000000  2014-01-12 02:10:54.545454544  \
# B                      -0.243044                       0.255213
# S                      -0.043847                      -0.751955
# J                      -0.120174                       0.409546
# A                       0.362442                       0.193926
#
#    2015-01-12 04:21:49.090909088  2016-01-12 06:32:43.636363632  \
# B                      -1.238056                       0.276234
# S                       1.288997                       0.357685
# J                       0.586629                      -0.903688
# A                      -1.136225                      -0.307291
#
#    2017-01-11 08:43:38.181818176  2018-01-11 10:54:32.727272704  \
# B                      -0.416452                      -0.203303
# S                       0.091228                       1.200429
# J                       0.373709                       0.100454
# A                      -0.424968                      -0.803684
#
#    2019-01-11 13:05:27.272727264  2020-01-11 15:16:21.818181824  \
# B                      -0.339523                      -0.340064
# S                       0.044399                       0.211631
# J                      -0.033089                       1.127301
# A                       0.094956                      -0.254531
#
#    2021-01-10 17:27:16.363636352  2022-01-10 19:38:10.909090880  \
# B                       1.628415                       1.295284
# S                       0.500079                       0.358820
# J                       0.625511                      -0.444901
# A                       1.296714                       0.183427
#
#    2023-01-10 21:49:05.454545408  2024-01-11 00:00:00.000000000
# B                       1.422142                       0.376687
# S                       0.359905                      -0.051869
# J                       0.062133                       0.117332
# A                      -1.457370                      -0.458123

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                                       S         J         B         A
# 2013-01-12 00:00:00.000000000 -0.043847 -0.120174 -0.243044  0.362442
# 2014-01-12 02:10:54.545454544 -0.751955  0.409546  0.255213  0.193926
# 2015-01-12 04:21:49.090909088  1.288997  0.586629 -1.238056 -1.136225
# 2016-01-12 06:32:43.636363632  0.357685 -0.903688  0.276234 -0.307291
# 2017-01-11 08:43:38.181818176  0.091228  0.373709 -0.416452 -0.424968
# 2018-01-11 10:54:32.727272704  1.200429  0.100454 -0.203303 -0.803684
# 2019-01-11 13:05:27.272727264  0.044399 -0.033089 -0.339523  0.094956
# 2020-01-11 15:16:21.818181824  0.211631  1.127301 -0.340064 -0.254531
# 2021-01-10 17:27:16.363636352  0.500079  0.625511  1.628415  1.296714
# 2022-01-10 19:38:10.909090880  0.358820 -0.444901  1.295284  0.183427
# 2023-01-10 21:49:05.454545408  0.359905  0.062133  1.422142 -1.457370
# 2024-01-11 00:00:00.000000000 -0.051869  0.117332  0.376687 -0.458123

# %%
df
# Out:
#                                       B         S         J         A
# 2013-01-12 00:00:00.000000000 -0.243044 -0.043847 -0.120174  0.362442
# 2014-01-12 02:10:54.545454544  0.255213 -0.751955  0.409546  0.193926
# 2015-01-12 04:21:49.090909088 -1.238056  1.288997  0.586629 -1.136225
# 2016-01-12 06:32:43.636363632  0.276234  0.357685 -0.903688 -0.307291
# 2017-01-11 08:43:38.181818176 -0.416452  0.091228  0.373709 -0.424968
# 2018-01-11 10:54:32.727272704 -0.203303  1.200429  0.100454 -0.803684
# 2019-01-11 13:05:27.272727264 -0.339523  0.044399 -0.033089  0.094956
# 2020-01-11 15:16:21.818181824 -0.340064  0.211631  1.127301 -0.254531
# 2021-01-10 17:27:16.363636352  1.628415  0.500079  0.625511  1.296714
# 2022-01-10 19:38:10.909090880  1.295284  0.358820 -0.444901  0.183427
# 2023-01-10 21:49:05.454545408  1.422142  0.359905  0.062133 -1.457370
# 2024-01-11 00:00:00.000000000  0.376687 -0.051869  0.117332 -0.458123

# %%
df.loc[:, ["J", "B"]]
# Out:
#                                       J         B
# 2013-01-12 00:00:00.000000000 -0.120174 -0.243044
# 2014-01-12 02:10:54.545454544  0.409546  0.255213
# 2015-01-12 04:21:49.090909088  0.586629 -1.238056
# 2016-01-12 06:32:43.636363632 -0.903688  0.276234
# 2017-01-11 08:43:38.181818176  0.373709 -0.416452
# 2018-01-11 10:54:32.727272704  0.100454 -0.203303
# 2019-01-11 13:05:27.272727264 -0.033089 -0.339523
# 2020-01-11 15:16:21.818181824  1.127301 -0.340064
# 2021-01-10 17:27:16.363636352  0.625511  1.628415
# 2022-01-10 19:38:10.909090880 -0.444901  1.295284
# 2023-01-10 21:49:05.454545408  0.062133  1.422142
# 2024-01-11 00:00:00.000000000  0.117332  0.376687

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                            index         B         S         J         A
# 0  2013-01-12 00:00:00.000000000 -0.243044 -0.043847 -0.120174  0.362442
# 1  2014-01-12 02:10:54.545454544  0.255213 -0.751955  0.409546  0.193926
# 2  2015-01-12 04:21:49.090909088 -1.238056  1.288997  0.586629 -1.136225
# 3  2016-01-12 06:32:43.636363632  0.276234  0.357685 -0.903688 -0.307291
# 4  2017-01-11 08:43:38.181818176 -0.416452  0.091228  0.373709 -0.424968
# 5  2018-01-11 10:54:32.727272704 -0.203303  1.200429  0.100454 -0.803684
# 6  2019-01-11 13:05:27.272727264 -0.339523  0.044399 -0.033089  0.094956
# 7  2020-01-11 15:16:21.818181824 -0.340064  0.211631  1.127301 -0.254531
# 8  2021-01-10 17:27:16.363636352  1.628415  0.500079  0.625511  1.296714
# 9  2022-01-10 19:38:10.909090880  1.295284  0.358820 -0.444901  0.183427
# 10 2023-01-10 21:49:05.454545408  1.422142  0.359905  0.062133 -1.457370
# 11 2024-01-11 00:00:00.000000000  0.376687 -0.051869  0.117332 -0.458123

# %%
df.drop("index", axis=1, inplace=True)

# %%
df
# Out:
#            B         S         J         A
# 0  -0.243044 -0.043847 -0.120174  0.362442
# 1   0.255213 -0.751955  0.409546  0.193926
# 2  -1.238056  1.288997  0.586629 -1.136225
# 3   0.276234  0.357685 -0.903688 -0.307291
# 4  -0.416452  0.091228  0.373709 -0.424968
# 5  -0.203303  1.200429  0.100454 -0.803684
# 6  -0.339523  0.044399 -0.033089  0.094956
# 7  -0.340064  0.211631  1.127301 -0.254531
# 8   1.628415  0.500079  0.625511  1.296714
# 9   1.295284  0.358820 -0.444901  0.183427
# 10  1.422142  0.359905  0.062133 -1.457370
# 11  0.376687 -0.051869  0.117332 -0.458123

# %%
df.loc[2:3, ["S","J","A"]]
# Out:
#           S         J         A
# 2  1.288997  0.586629 -1.136225
# 3  0.357685 -0.903688 -0.307291

# %%
df.iloc[0:3,0:2]
# Out:
#           B         S
# 0 -0.243044 -0.043847
# 1  0.255213 -0.751955
# 2 -1.238056  1.288997

# %%
df.iloc[[0,6,11],[0,-1]]
# Out:
#            B         A
# 0  -0.243044  0.362442
# 6  -0.339523  0.094956
# 11  0.376687 -0.458123
